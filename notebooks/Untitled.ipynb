# %%
import os
import numpy as np
import scanpy as sc
import anndata as ad
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(5, 5)
plt.rcParams['figure.dpi'] = 200
sc.settings.verbosity = 3
sc.settings.figdir = '../figures/'
sc.logging.print_versions()
#results_file = './write/results.h5ad'


# %load_ext autoreload
# %autoreload 2
# Out:
# scanpy==1.5.1 anndata==0.7.3 umap==0.4.4 numpy==1.19.0 scipy==1.5.0 pandas==1.0.5 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.2
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pvn = sc.read('../data/processed/PVN_renamed_latest.h5ad')
adrenal = sc.read('../data/processed/adrenal_renamed_latest.h5ad')
pituitary = sc.read('../data/processed/pituitary_renamed_latest.h5ad')

# %%
adata = pvn.concatenate([adrenal, pituitary], batch_key='tissue')

# %%
plt.rcParams['figure.figsize'] = (5, 5)
sc.pl.violin(pvn, keys='n_counts', groupby='condition', save='_pvn_ncounts.png')
sc.pl.violin(pvn, keys='n_genes', groupby='condition', save='_pvn_ngenes.png')
sc.pl.violin(pvn, keys='mt_frac', groupby='condition', save='_pvn_mtfrac.png')
sc.pl.violin(adrenal, keys='n_counts', groupby='condition', save='_adrenal_ncounts.png')
sc.pl.violin(adrenal, keys='n_genes', groupby='condition', save='_adrenal_ngenes.png')
sc.pl.violin(adrenal, keys='mt_frac', groupby='condition', save='_adrenal_mtfrac.png')
sc.pl.violin(pituitary, keys='n_counts', groupby='condition', save='_pituitary_ncounts.png')
sc.pl.violin(pituitary, keys='n_genes', groupby='condition', save='_pituitary_ngenes.png')
sc.pl.violin(pituitary, keys='mt_frac', groupby='condition', save='_pituitary_mtfrac.png')
# Out:
# WARNING: saving figure to file ../figures/violin_pvn_ncounts.png
# WARNING: saving figure to file ../figures/violin_pvn_ngenes.png
# WARNING: saving figure to file ../figures/violin_pvn_mtfrac.png
# WARNING: saving figure to file ../figures/violin_adrenal_ncounts.png
# WARNING: saving figure to file ../figures/violin_adrenal_ngenes.png
# WARNING: saving figure to file ../figures/violin_adrenal_mtfrac.png
# WARNING: saving figure to file ../figures/violin_pituitary_ncounts.png
# WARNING: saving figure to file ../figures/violin_pituitary_ngenes.png
# WARNING: saving figure to file ../figures/violin_pituitary_mtfrac.png
